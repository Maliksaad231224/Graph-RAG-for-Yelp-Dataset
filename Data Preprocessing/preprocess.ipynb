# %%
import pandas as pd

# %%
customer = pd.read_csv(r'olist_customers_dataset_enhanced.csv')
payments = pd.read_csv(r'olist_order_payments_dataset_enhanced.csv')
reviews = pd.read_csv(r'olist_order_reviews_dataset_enhanced.csv')
orders = pd.read_csv(r'olist_orders_dataset_enhanced.csv')
products = pd.read_csv(r'olist_products_dataset_enhanced.csv')
sellers = pd.read_csv(r'olist_sellers_dataset_enhanced.csv')
translations = pd.read_csv(r'product_category_name_translation.csv')
items = pd.read_csv(r'olist_order_items_dataset_enhanced.csv')

# %%
print("customer columns:",customer.columns)
print("payments columns:",payments.columns)
print("reviews columns:",reviews.columns)
print("orders columns:",orders.columns)
print("products columns:",products.columns)
print("sellers columns:",sellers.columns)
print("translations columns:",translations.columns)
print("items columns:",items.columns)
# Out:
# customer columns: Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'total_orders',
#        'first_purchase_date', 'last_purchase_date', 'customer_lifetime_days',
#        'total_spending', 'avg_order_value', 'avg_review_score', 'review_count',
#        'customer_segment'],
#       dtype='object')
# payments columns: Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'order_total_with_freight',
#        'order_status', 'payment_percentage', 'payment_method_category',
#        'installment_risk'],
#       dtype='object')
# reviews columns: Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp', 'order_status', 'delivery_performance',
#        'review_sentiment', 'has_comment', 'response_time_hours'],
#       dtype='object')
# orders columns: Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'approval_to_delivery_days', 'estimated_delivery_days',
#        'delivery_delay_days', 'order_item_total', 'order_freight_total',
#        'order_total_with_freight', 'num_items', 'order_review_score',
#        'delivery_performance', 'customer_segment'],
#       dtype='object')
# products columns: Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'product_category_name_english', 'product_volume_cm3',
#        'product_density_g_per_cm3', 'product_complexity_score',
#        'size_category', 'units_sold', 'total_revenue', 'avg_price',
#        'avg_product_rating'],
#       dtype='object')
# sellers columns: Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state',
#        'total_orders', 'total_revenue', 'avg_item_price', 'avg_rating',
#        'seller_tier', 'on_time_deliveries', 'on_time_delivery_rate'],
#       dtype='object')
# translations columns: Index(['product_category_name', 'product_category_name_english'], dtype='object')
# items columns: Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value',
#        'product_category_name', 'product_category_name_english',
#        'estimated_profit', 'item_total_with_freight', 'price_category',
#        'order_status', 'delivery_performance', 'order_review_score'],
#       dtype='object')

# %%
customer=customer[:50000]

# %%
valid_customers = customer["customer_id"].unique()
orders = orders[orders["customer_id"].isin(valid_customers)]

valid_orders = orders["order_id"].unique()
items = items[items["order_id"].isin(valid_orders)]

payments = payments[payments["order_id"].isin(valid_orders)]

reviews = reviews[reviews["order_id"].isin(valid_orders)]

valid_products = items["product_id"].unique()
products = products[products["product_id"].isin(valid_products)]

valid_sellers = items["seller_id"].unique()
sellers = sellers[sellers["seller_id"].isin(valid_sellers)]

if "product_category_name" in items.columns:
    valid_categories = items["product_category_name"].dropna().unique()
    translations = translations[translations["product_category_name"].isin(valid_categories)]

# %%
items
# Out:
#                                 order_id  order_item_id  \
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5       00048cc3ae777c65dbb7d2a0634bc1ea              1
# 7       000576fe39319847cbb9d288c5617fa6              1
# ...                                  ...            ...
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
# 112644  fffbee3b5462987e66fb49b1c5411df2              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# 5       ef92defde845ab8450f9d70c526ef70f  6426d21aca402a131fc0a5d0960a3c90
# 7       557d850972a7d6f792fd18ae1400d9b6  5996cddab893a4652a15592fb58ab8db
# ...                                  ...                               ...
# 112643  43423cdffde7fda63d0414ed38c11a73  b1fc4f64df5a0e8b6913ab38803c57a9
# 112644  6f0169f259bb0ff432bfff7d829b9946  213b25e6f54661939f11710a6fddb871
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value   product_category_name  \
# 1       2017-05-03 11:05:13  239.90          19.93                pet_shop
# 2       2018-01-18 14:48:30  199.00          17.87        moveis_decoracao
# 4       2017-02-13 13:57:51  199.90          18.14      ferramentas_jardim
# 5       2017-05-23 03:55:27   21.90          12.69   utilidades_domesticas
# 7       2018-07-10 12:30:45  810.00          70.75      ferramentas_jardim
# ...                     ...     ...            ...                     ...
# 112643  2017-11-03 02:55:58   55.00          34.19      relogios_presentes
# 112644  2018-06-28 09:58:03  119.85          20.03         casa_construcao
# 112646  2018-07-20 04:31:48  350.00          36.53  informatica_acessorios
# 112647  2017-10-30 17:14:25   99.90          16.95           esporte_lazer
# 112649  2018-06-12 17:10:13   43.00          12.79         cama_mesa_banho
#
#        product_category_name_english  estimated_profit  \
# 1                           pet_shop             95.96
# 2                    furniture_decor             79.60
# 4                       garden_tools             79.96
# 5                         housewares              8.76
# 7                       garden_tools            324.00
# ...                              ...               ...
# 112643                 watches_gifts             22.00
# 112644             home_construction             47.94
# 112646         computers_accessories            140.00
# 112647                sports_leisure             39.96
# 112649                bed_bath_table             17.20
#
#         item_total_with_freight price_category order_status  \
# 1                        259.83        Premium    delivered
# 2                        216.87      Mid-Range    delivered
# 4                        218.04      Mid-Range    delivered
# 5                         34.59         Budget    delivered
# 7                        880.75         Luxury    delivered
# ...                         ...            ...          ...
# 112643                    89.19      Mid-Range    delivered
# 112644                   139.88      Mid-Range    delivered
# 112646                   386.53        Premium    delivered
# 112647                   116.85      Mid-Range    delivered
# 112649                    55.79         Budget    delivered
#
#        delivery_performance  order_review_score
# 1                   On-Time                 4.0
# 2                   On-Time                 5.0
# 4                   On-Time                 5.0
# 5                   On-Time                 4.0
# 7                   On-Time                 5.0
# ...                     ...                 ...
# 112643              On-Time                 4.0
# 112644              On-Time                 5.0
# 112646              On-Time                 5.0
# 112647              On-Time                 5.0
# 112649              On-Time                 5.0
#
# [56639 rows x 15 columns]

# %%
products.to_csv(r'olist_products_dataset_enhanced_sample.csv', index=False)
customer.to_csv(r'olist_customers_dataset_enhanced_sample.csv', index=False)
payments.to_csv(r'olist_order_payments_dataset_enhanced_sample.csv', index=False)
reviews.to_csv(r'olist_order_reviews_dataset_enhanced_sample.csv', index=False)
orders.to_csv(r'olist_orders_dataset_enhanced_sample.csv', index=False)
sellers.to_csv(r'olist_sellers_dataset_enhanced_sample.csv', index=False)
translations.to_csv(r'product_category_name_translation_sample.csv', index=False)  
items.to_csv(r'olist_order_items_dataset_enhanced_sample.csv', index=False)
